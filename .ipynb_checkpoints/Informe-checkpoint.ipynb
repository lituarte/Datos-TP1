# %% [markdown]
# # TP 1 - 2C 2018
# # GRUPO 11
# # ANÁLISIS EXPLORATORIO

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm
import datetime as DT
import calendar

from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize
from matplotlib.patches import Polygon

# %matplotlib inline

# %%
df_eventos = pd.read_csv('/home/lautaro/Desktop/events.csv',low_memory=False)

# %%
# función para convertir fecha a día de la semana.
def fecha_a_dia(fecha):
    return calendar.day_name[fecha.weekday()]

def model_split(model):
    return model.str.split(' ', expand=True)

def numero_a_mes(numero):
    return calendar.month_abbr[numero]

df_eventos['timestamp'] = pd.to_datetime(df_eventos['timestamp'], format='%Y-%m-%d')
df_eventos['timestamp_diaDelAnio'] = df_eventos["timestamp"].dt.dayofyear
df_eventos['timestamp_diaDeLaSemana'] = df_eventos["timestamp"].dt.dayofweek
df_eventos['timestamp_diaDeLaSemana_desc'] = df_eventos['timestamp'].map(fecha_a_dia)
df_eventos['timestamp_mes'] = df_eventos['timestamp'].dt.month
df_eventos["timestamp_mes_desc"] = df_eventos["timestamp_mes"].map(numero_a_mes)
df_eventos['model_marca'] =df_eventos.model.str.strip().str.split(' ', expand=True)[0]
df_eventos['model_tipo'] =df_eventos.model.str.strip().str.split(' ', expand=True)[1]
df_eventos['model_subtipo'] =df_eventos.model.str.strip().str.split(' ', expand=True)[2]
df_eventos['total'] = 1 # Para contabilizar eventos

# %% [markdown]
# # 1. Vista general del dataset

# %%
df_eventos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011288 entries, 0 to 1011287
# Data columns (total 29 columns):
# timestamp                       1011288 non-null datetime64[ns]
# event                           1011288 non-null object
# person                          1011288 non-null object
# url                             82756 non-null object
# sku                             563838 non-null object
# model                           564284 non-null object
# condition                       563836 non-null object
# storage                         563836 non-null object
# color                           563836 non-null object
# skus                            221699 non-null object
# search_term                     48967 non-null object
# staticpage                      3598 non-null object
# campaign_source                 82796 non-null object
# search_engine                   50957 non-null object
# channel                         87378 non-null object
# new_vs_returning                87378 non-null object
# city                            87378 non-null object
# region                          87378 non-null object
# country                         87378 non-null object
# device_type                     87378 non-null object
# screen_resolution               87378 non-null object
# operating_system_version        87378 non-null object
# browser_version                 87378 non-null object
# timestamp_diaDelAnio            1011288 non-null int64
# timestamp_diaDeLaSemana         1011288 non-null int64
# timestamp_diaDeLaSemana_desc    1011288 non-null object
# model_marca                     564284 non-null object
# model_tipo                      564284 non-null object
# model_subtipo                   352675 non-null object
# dtypes: datetime64[ns](1), int64(2), object(26)
# memory usage: 223.8+ MB

# %%
df_eventos.head(10)
# Out:
#             timestamp            event    person                         url  \
# 0 2018-05-31 23:38:05  ad campaign hit  0004b0a2   /comprar/iphone/iphone-5s
# 1 2018-05-31 23:38:05     visited site  0004b0a2                         NaN
# 2 2018-05-31 23:38:09   viewed product  0004b0a2                         NaN
# 3 2018-05-31 23:38:40         checkout  0004b0a2                         NaN
# 4 2018-05-29 13:29:25   viewed product  0006a21a                         NaN
# 5 2018-05-29 13:29:26     visited site  0006a21a                         NaN
# 6 2018-05-29 13:29:27  ad campaign hit  0006a21a  /comprar/samsung/galaxy-s8
# 7 2018-05-29 13:29:35         checkout  0006a21a                         NaN
# 8 2018-04-09 20:12:31  generic listing  000a54b2                         NaN
# 9 2018-04-09 20:12:31     visited site  000a54b2                         NaN
#
#        sku              model condition storage           color  \
# 0      NaN                NaN       NaN     NaN             NaN
# 1      NaN                NaN       NaN     NaN             NaN
# 2   2694.0          iPhone 5s       Bom    32GB  Cinza espacial
# 3   2694.0          iPhone 5s       Bom    32GB  Cinza espacial
# 4  15338.0  Samsung Galaxy S8       Bom    64GB         Dourado
# 5      NaN                NaN       NaN     NaN             NaN
# 6      NaN                NaN       NaN     NaN             NaN
# 7  15338.0  Samsung Galaxy S8       Bom    64GB         Dourado
# 8      NaN                NaN       NaN     NaN             NaN
# 9      NaN                NaN       NaN     NaN             NaN
#
#                                                 skus        ...          \
# 0                                                NaN        ...
# 1                                                NaN        ...
# 2                                                NaN        ...
# 3                                                NaN        ...
# 4                                                NaN        ...
# 5                                                NaN        ...
# 6                                                NaN        ...
# 7                                                NaN        ...
# 8  10310,13333,13347,9902,9944,12774,12801,12744,...        ...
# 9                                                NaN        ...
#
#     browser_version timestamp_diaDelAnio timestamp_diaDeLaSemana  \
# 0               NaN                  151                       3
# 1  Chrome Mobile 39                  151                       3
# 2               NaN                  151                       3
# 3               NaN                  151                       3
# 4               NaN                  149                       1
# 5       Android 5.1                  149                       1
# 6               NaN                  149                       1
# 7               NaN                  149                       1
# 8               NaN                   99                       0
# 9       Chrome 65.0                   99                       0
#
#   timestamp_diaDeLaSemana_desc model_marca model_tipo model_subtipo total  \
# 0                     Thursday         NaN        NaN           NaN     1
# 1                     Thursday         NaN        NaN           NaN     1
# 2                     Thursday      iPhone         5s          None     1
# 3                     Thursday      iPhone         5s          None     1
# 4                      Tuesday     Samsung     Galaxy            S8     1
# 5                      Tuesday         NaN        NaN           NaN     1
# 6                      Tuesday         NaN        NaN           NaN     1
# 7                      Tuesday     Samsung     Galaxy            S8     1
# 8                       Monday         NaN        NaN           NaN     1
# 9                       Monday         NaN        NaN           NaN     1
#
#   timestamp_mes timestamp_mes_desc
# 0             5                May
# 1             5                May
# 2             5                May
# 3             5                May
# 4             5                May
# 5             5                May
# 6             5                May
# 7             5                May
# 8             4                Apr
# 9             4                Apr
#
# [10 rows x 32 columns]

# %% [markdown]
# ¿Cuáles son los eventos con los que contamos?

# %%
print(df_eventos['event'].unique())
# Out:
# ['ad campaign hit' 'visited site' 'viewed product' 'checkout'
#  'generic listing' 'search engine hit' 'brand listing' 'searched products'
#  'conversion' 'staticpage' 'lead']

# %% [markdown]
# ¿En qué países nos estamos manejando?

# %%
print(df_eventos['country'].unique())
# Out:
# [nan 'Brazil' 'Unknown' 'United States' 'Argentina' 'Russia' 'Canada'
#  'Netherlands' 'France' 'Paraguay' 'Mexico' 'Mozambique' 'Philippines'
#  'Israel' 'Bangladesh' 'Italy' 'United Kingdom' 'Angola' 'Portugal'
#  'Uzbekistan' 'Venezuela' 'Belize' 'Colombia' 'China' 'French Guiana'
#  'Algeria' 'Japan' 'India' 'Dominican Republic' 'Ireland' 'Zimbabwe'
#  'Turkey' 'Germany' 'Sri Lanka' 'Rwanda' 'Romania' 'Saudi Arabia' 'Morocco'
#  'Uruguay' 'Switzerland' 'Cape Verde' 'Denmark' 'Peru' 'Guadeloupe'
#  'Poland' 'South Africa' 'Spain']

# %% [markdown]
# ¿Qué productos estamos comercializando?

# %%
print(df_eventos['model'].unique())
# Out:
# [nan 'iPhone 5s' 'Samsung Galaxy S8' 'Motorola Moto Z Play' 'iPhone 7 Plus'
#  'iPhone 6S' 'iPhone 4G' 'iPhone 4S' 'Samsung Galaxy J5' 'iPhone 5c'
#  'iPhone 7' 'iPhone 6' 'Samsung Galaxy S6 Flat' 'Motorola Moto G3 4G'
#  'Motorola Moto G4 Play DTV' 'Asus Zenfone 2' 'iPhone 5'
#  'Motorola Moto X Play 4G Dual' 'Motorola Moto X2' 'Samsung Galaxy A7 2016'
#  'iPhone 6S Plus' 'Samsung Galaxy Core Plus Duos TV'
#  'Samsung Galaxy Win Duos' 'Samsung Galaxy S7' 'Samsung Galaxy Core 2 Duos'
#  'Samsung Galaxy J7' 'Quantum GO 4G' 'Lenovo Vibe A7010 Dual Chip'
#  'Sony Xperia M4 Aqua' 'Motorola Moto G4 Plus'
#  'Samsung Galaxy J7 2016 Metal' 'Samsung Galaxy J1 2016' 'Lenovo Vibe K5'
#  'Motorola Moto G2 3G Dual' 'Samsung Galaxy Y Duos'
#  'Motorola Moto G2 4G Dual' 'Sony Xperia M4 Aqua Dual' 'Samsung Galaxy S5'
#  'Motorola Moto Z2 Play' 'Motorola Moto MAXX ' 'Motorola Moto X Force'
#  'Samsung Galaxy S7 Edge' 'Sony Xperia Z3 Plus' 'Sony Xperia Z3 Dual'
#  'LG G4 H815P' 'LG G4 H818P' 'Samsung Galaxy S6 Edge' 'iPhone 6 Plus'
#  'Samsung Galaxy Note 8' 'Samsung Galaxy J7 Prime'
#  'Samsung Galaxy Note 3 Neo Duos' 'Samsung Galaxy A5'
#  'iPad Air 2 Wi-Fi + 4G' 'LG K10 Novo' 'LG G5 SE' 'Samsung Galaxy A7 2017'
#  'Samsung Galaxy Note 5' 'Motorola Moto G5 Plus' 'Samsung Galaxy A7'
#  'iPhone SE' 'Samsung Galaxy S6 Edge Plus' 'Motorola Moto Z Power Edition'
#  'Samsung Galaxy S8 Plus' 'iPhone X' 'iPad 4 Wi-Fi + 4G' 'iPhone 8'
#  'Motorola Moto G4 DTV' 'Samsung Galaxy J1 Mini' 'Samsung Galaxy Note 3'
#  'Samsung Galaxy Note 4' 'Samsung Galaxy A5 2017' 'Motorola Moto X Style'
#  'Samsung Galaxy Note Edge' 'Sony Xperia Z5' 'iPad Air 2 Wi-Fi'
#  'Samsung Galaxy S5 Mini Duos' 'Motorola Moto G5 '
#  'Samsung Galaxy J2 4G Duos TV' 'Samsung Galaxy J2 4G Duos '
#  'Motorola Moto G4 Play' 'Motorola Moto Z'
#  'Samsung Galaxy S5 New Edition Duos ' 'Samsung Galaxy E7'
#  'Motorola Moto G3 HDTV' 'Samsung Galaxy J5 2016 Metal'
#  'Samsung Galaxy Gran Prime Duos TV' 'Samsung Galaxy J5 Prime'
#  'Samsung Galaxy Tab E 9.6 Wi-Fi' 'Samsung Galaxy Tab E 7 Wi-Fi + 3G'
#  'Samsung Galaxy Gran Prime Duos' 'Samsung Galaxy Gran Neo Plus Duos'
#  'Quantum Muv' 'Samsung Galaxy Mega Duos' 'iPad 2 Wi-Fi'
#  'Samsung Galaxy Tab S 8.4 Wi-Fi + 4G'
#  'Samsung Galaxy Tab A com S Pen 8 Wi-Fi + 4G' 'Asus Live'
#  'Asus Zenfone 2 Laser' 'Samsung Galaxy Tab S 10.5 Wi-Fi'
#  'Samsung Galaxy Young 2 Duos TV' 'Motorola Moto G1 4G'
#  'Asus Zenfone 3 Zoom' 'iPad 4 Wi-Fi' 'Asus Zenfone Go'
#  'Samsung Galaxy Tab E 7 Wi-Fi' 'Samsung Galaxy Tab E 9.6 Wi-Fi + 3G'
#  'iPad Mini 2 Wi-Fi' 'Quantum Muv Pro' 'Motorola Moto E2 DTV'
#  'Samsung Gear Fit 2 Grande' 'LG K4' 'Samsung Gear S3 Classic'
#  'Quantum GO 3G' 'iPad Mini 2 Wi-Fi + 4G'
#  'Samsung Galaxy S3 Neo Duos i9300i' 'LG L80 Dual' 'Motorola RAZR I'
#  'Quantum Muv Up' 'Blackberry Blackberry Z30']

# %% [markdown]
# # 2. Análisis preliminar del set de datos

# %% [markdown]
# En esta sección vamos a incluir todos los análisis que consideramos debemos realizar antes de cualquier otro ya que de no ser tenidos en cuenta pueden causar análisis con resultados contaminados o erróneos.

# %% [markdown]
# ## 2.1 Análisis de rango de fechas

# %% [markdown]
# Primero vamos a ver entre que fechas suceden los eventos que nos fueron otorgados, empiezo buscando la primera disponible.

# %%
df_eventos["timestamp"].min()
# Out:
# Timestamp('2018-01-01 07:32:26')

# %% [markdown]
# La primera fecha es el primero de enero de este año. A continuación busco la última.

# %%
df_eventos["timestamp"].max()
# Out:
# Timestamp('2018-06-15 23:59:31')

# %% [markdown]
# La ultima fecha es de mitad de junio asi que si hacemos estadisticas por mes debemos tener en cuenta que dicho mes no esta completamente cargado.

# %% [markdown]
# # 3. Análisis del tráfico del sitio

# %% [markdown]
# ## 3.1 Cantidad de visitas

# %%
    cantidad_trafico = df_eventos.loc[df_eventos["event"] == "visited site",
                                      ["timestamp","timestamp_diaDeLaSemana", "timestamp_diaDeLaSemana_desc","timestamp_mes","timestamp_mes_desc", "total"]]

# %%
cantidad_trafico.head()
# Out:
#              timestamp  timestamp_diaDeLaSemana timestamp_diaDeLaSemana_desc  \
# 1  2018-05-31 23:38:05                        3                     Thursday
# 5  2018-05-29 13:29:26                        1                      Tuesday
# 9  2018-04-09 20:12:31                        0                       Monday
# 16 2018-05-24 11:21:07                        3                     Thursday
# 45 2018-04-06 05:12:05                        4                       Friday
#
#     timestamp_mes timestamp_mes_desc  total
# 1               5                May      1
# 5               5                May      1
# 9               4                Apr      1
# 16              5                May      1
# 45              4                Apr      1

# %% [markdown]
# ### 3.1.1 Cantidad de visitas por mes

# %%
visitas_por_mes = cantidad_trafico.loc[:,["timestamp_mes", "timestamp_mes_desc", "total"]]

# %%
visitas_por_mes = visitas_por_mes.groupby(["timestamp_mes", "timestamp_mes_desc"], as_index=False).sum()
visitas_por_mes
# Out:
#    timestamp_mes timestamp_mes_desc  total
# 0              1                Jan   2135
# 1              2                Feb   2790
# 2              3                Mar   7247
# 3              4                Apr  12650
# 4              5                May  40137
# 5              6                Jun  22419

# %%
visitas_por_mes.plot(kind="bar",rot=0, figsize=(7,7), legend=False, x="timestamp_mes_desc", y="total")
plt.title("Cantidad de visitas por mes")
plt.xlabel("Mes")
plt.ylabel("Cantidad de visitas")
# Out:
# Text(0,0.5,'Cantidad de visitas')

# %% [markdown]
# Por el análisis que hicimos del rango de fechas (2.1), sabemos que los datos de junio son parciales.

# %% [markdown]
# Podemos observar un incremento en el trafico del sitio web notable por mes

# %% [markdown]
# ## 3.2 Origen del tráfico

# %% [markdown]
# ### 3.2.1 Países desde donde se accede a Trocafone.

# %%
df_eventos_groupby_country = df_eventos.groupby(['country']).sum()
df_eventos_groupby_country = df_eventos_groupby_country[['total']].reset_index()
df_eventos_groupby_country.set_index('country', inplace=True)

# %%
df_eventos_groupby_country.sort_values('total', ascending=False)
# Out:
#                     total
# country
# Brazil              84308
# Unknown              2313
# United States         465
# Argentina              94
# Canada                 35
# Netherlands            13
# France                 13
# Mozambique             12
# United Kingdom         12
# Japan                  11
# Poland                  9
# French Guiana           8
# Italy                   7
# Romania                 7
# Portugal                7
# Dominican Republic      6
# Guadeloupe              6
# Russia                  6
# Germany                 5
# Colombia                4
# Bangladesh              4
# Paraguay                4
# Switzerland             3
# India                   2
# Angola                  2
# Morocco                 2
# Turkey                  1
# Sri Lanka               1
# South Africa            1
# Uruguay                 1
# Uzbekistan              1
# Venezuela               1
# Spain                   1
# Algeria                 1
# Saudi Arabia            1
# Rwanda                  1
# Philippines             1
# Peru                    1
# Mexico                  1
# Israel                  1
# Ireland                 1
# Denmark                 1
# China                   1
# Cape Verde              1
# Belize                  1
# Zimbabwe                1

# %%
df_eventos_groupby_country_top5 = df_eventos_groupby_country.sort_values('total', ascending=False).head(5)
df_eventos_groupby_country_top5
# Out:
#                total
# country
# Brazil         84308
# Unknown         2313
# United States    465
# Argentina         94
# Canada            35

# %%
df_eventos_groupby_country_top5.plot(kind='bar',stacked=True, rot=90, figsize=(15,10),color=['green'], fontsize=13, legend=False)
plt.title('Top 10 - Paises con mas eventos', fontsize=20);
plt.ylabel('Cantidad', fontsize=16);
plt.xlabel('Paises', fontsize=20);

# %% [markdown]
# Como primera observación vemos que la fuente de datos es principalmente Brasil, es de donde surge la principal operatoria de la empresa. Hay también un porcentaje pequeño que no se conoce el origen. Es muy amplia la diferencia a favor de Brasil por lo tanto no se elimina ya que es un análisis inicial. Luego siguen (y muy por debajo) Estados Unidos, Argentina y Canada.

# %% [markdown]
# ### 3.2.2 Personas más activas

# %%
df_eventos_groupby_person = df_eventos.groupby(['person']).sum()
df_eventos_groupby_person = df_eventos_groupby_person[['total']].reset_index()
df_eventos_groupby_person.set_index('person', inplace=True)

# %%
df_eventos_groupby_person_top10 = df_eventos_groupby_person.sort_values('total', ascending=False).head(10)
df_eventos_groupby_person_top10
# Out:
#           total
# person
# 71492f2b   2771
# 6b07be7b   2770
# 285101a1   2140
# 3e34b3cf   1877
# 2d5a84c1   1800
# 5f25cb5d   1797
# 5af7e2bc   1773
# 3b5a5833   1705
# d7e60792   1352
# cd6e0b8d   1254

# %%
df_eventos_groupby_person_top10.plot(kind='bar',stacked=True, rot=90, figsize=(15,10),color=['green'], fontsize=13)
plt.title('Top 10 - Personas con mas eventos', fontsize=20);
plt.ylabel('Cantidad', fontsize=16);
plt.xlabel('Persona', fontsize=20);

# %% [markdown]
# # 4. Análisis de popularidad

# %% [markdown]
# En esta sección analizamos la popularidad de distintos productos, modelos y marcas según distintos parámetros

# %% [markdown]
# ## 4.1 Popularidad de marcas en eventos

# %%
df_eventos_groupby_model = df_eventos.groupby(['model_marca']).sum()
df_eventos_groupby_model = df_eventos_groupby_model[['total']].reset_index()
df_eventos_groupby_model.set_index('model_marca', inplace=True)
df_eventos_groupby_model = df_eventos_groupby_model.sort_values('total', ascending=False)

# %%
df_eventos_groupby_model
# Out:
#               total
# model_marca
# iPhone       256585
# Samsung      218127
# Motorola      63518
# LG             9724
# Sony           7025
# Lenovo         4779
# Asus           2091
# iPad           1914
# Quantum         520
# Blackberry        1

# %%
df_eventos_groupby_model.head(10).plot(kind='bar',stacked=True, rot=90, figsize=(15,10),color=['blue'], fontsize=13, legend=False)
plt.title('TOP 10 - Marcas de Dispositivos mas mencionadas', fontsize=20);
plt.ylabel('Cantidad', fontsize=16);
plt.xlabel('Marcas', fontsize=20);

# %% [markdown]
# Es clara la importancia tanto de de Apple como Samsnung como lideres del sector, seguido por Motorola. Las restantes marcas tiene una presencia menos importante.

# %% [markdown]
# ## 4.2 Popularidad de palabras buscadas

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
busquedas = df_eventos.loc[df_eventos["event"] == "searched products",["timestamp","search_term"]]
busquedas = busquedas.loc[busquedas["search_term"].notnull(),:]

# %%
text = ' '.join(busquedas["search_term"])

# Create and generate a word cloud image:
wordcloud = WordCloud(width=800, height=400, collocations=False, background_color="white").generate(text)

# Display the generated image:
plt.figure(figsize=[15,15])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Wordcloud de palabras buscadas", fontsize=30)
# Out:
# Text(0.5,1,'Wordcloud de palabras buscadas')

# %% [markdown]
# ## 4.3 Modelos con mayor cantidad de solicitudes de stock

# %%
solicitudes_stock_mes = df_eventos.loc[df_eventos["event"] == "lead",["model", "timestamp_mes", "timestamp_mes_desc", "total"]]
solicitudes_stock_mes = solicitudes_stock_mes.groupby(["timestamp_mes", "timestamp_mes_desc", "model"], as_index=False).sum()

# %%
solicitudes_stock_mes.groupby(["timestamp_mes_desc"], as_index=False).max()
# Out:
#   timestamp_mes_desc  timestamp_mes          model  total
# 0                Apr              4      iPhone SE     20
# 1                Feb              2  iPhone 7 Plus      4
# 2                Jan              1      iPhone SE      3
# 3                Jun              6       iPhone X      9
# 4                Mar              3      iPhone SE     16
# 5                May              5       iPhone X     10

# %% [markdown]
# Hay que tener en cuenta que los datos de junio son parciales (2.1)

# %% [markdown]
# Teniendo en cuenta que los últimos datos que tenemos cargados son de junio podemos hacer de cuenta que es el mes en el que estamos actualmente y queremos saber cuantos pedidos de stock tenemos para poder actuar en consecuencia.

# %%
solicitudes_junio = solicitudes_stock_mes.loc[solicitudes_stock_mes["timestamp_mes"] == 6,
                                              ["model", "total"]].sort_values(by="total", ascending=False)
solicitudes_junio.nlargest(20, "total")
# Out:
#                               model  total
# 182                        iPhone 8      9
# 163           Motorola Moto G5 Plus      9
# 165          Motorola Moto G5S Plus      7
# 162           Motorola Moto G4 Plus      7
# 172         Samsung Galaxy J7 Prime      6
# 171           Samsung Galaxy J7 PRO      5
# 178                       iPhone 6S      5
# 183                   iPhone 8 Plus      4
# 179                  iPhone 6S Plus      4
# 161        Motorola Moto G2 3G Dual      4
# 181                   iPhone 7 Plus      3
# 154                     LG K10 Novo      3
# 177                   iPhone 6 Plus      3
# 170           Samsung Galaxy J5 PRO      2
# 174  Samsung Galaxy Tab E 9.6 Wi-Fi      2
# 166          Motorola Moto Z2 Force      2
# 167           Motorola Moto Z2 Play      2
# 164               Motorola Moto G5S      2
# 156                           LG K4      2
# 180                        iPhone 7      2

# %% [markdown]
# ## 4.4 Productos más deseados

# %%
views = df_eventos.loc[df_eventos["event"] == "viewed product", ["person", "model"]]
compras = df_eventos.loc[df_eventos["event"] == "conversion", ["person", "model"]]
views["cantidad_vistos"] = 1
compras["comprado"] = 1

# %%
views = views.groupby(["person","model"], as_index=False).sum()
compras = compras.groupby(["person", "model"], as_index=False).sum()

# %%
merged = views.merge(compras, left_on=["person","model"], right_on=["person","model"],how="outer")

# %%
views_sin_compras = merged.loc[merged["comprado"].isnull(),["person","model","cantidad_vistos"]]

# %%
views_sin_compras.nlargest(10, "cantidad_vistos")
# Out:
#          person      model  cantidad_vistos
# 84887  c501ff3a  iPhone 5c            812.0
# 93934  d7e60792   iPhone 7            532.0
# 59054  88cabe99  iPhone 6S            495.0
# 24892  3b5a5833  iPhone SE            466.0
# 24886  3b5a5833   iPhone 6            397.0
# 22707  35cf2bcd   iPhone 6            342.0
# 55518  7ffacfa4  iPhone 5s            311.0
# 46083  6d2fe2db  iPhone 5s            304.0
# 55360  7fa9d215  iPhone 6S            304.0
# 63198  9250d410  iPhone 6S            286.0

# %% [markdown]
# Hasta acá tenemos la lista de los usuarios que más han visto un modelo de celular sin comprarlo, estos datos nos pueden servir para ofrecerles a esos usuarios en particular algún tipo de descuento exclusivo para motivarlos a concretar esa compra del producto que tanto quieren.

# %% [markdown]
# También podemos obtener qué modelos de celular son los más deseados entre nuestros usuarios:

# %%
views_sin_compras = views_sin_compras.drop(columns={"person"})

# %%
views_sin_compras = views_sin_compras.groupby("model", as_index=False).mean().sort_values(by="cantidad_vistos", ascending=False)

# %%
views_sin_compras.head(20)
# Out:
#                             model  cantidad_vistos
# 132        Samsung Galaxy S7 Edge         8.401549
# 189                     iPhone 5s         7.777821
# 188                     iPhone 5c         7.605176
# 190                      iPhone 6         7.509240
# 192                     iPhone 6S         7.309422
# 194                      iPhone 7         6.877832
# 198                     iPhone SE         6.735622
# 46          Motorola Moto G4 Plus         6.569963
# 195                 iPhone 7 Plus         6.193470
# 128        Samsung Galaxy S6 Edge         5.430294
# 193                iPhone 6S Plus         5.240562
# 131             Samsung Galaxy S7         5.203202
# 191                 iPhone 6 Plus         5.200521
# 133             Samsung Galaxy S8         5.101529
# 187                      iPhone 5         4.937856
# 134        Samsung Galaxy S8 Plus         4.932118
# 72         Samsung Galaxy A5 2017         4.872762
# 53   Motorola Moto X Play 4G Dual         4.736682
# 56               Motorola Moto X2         4.650143
# 186                     iPhone 4S         4.587349

# %% [markdown]
# Lo que nos dice esta tabla es la cantidad de veces que entra a ver un producto un usuario que no lo compró, en inglés a estas personas se las llama "window shoppers". Es muy probable que esta gente este a la espera del precio adecuado y Trocafone sea uno de los tantos lugares que visita para encontrar ese precio.

# %%
views_sin_compras.head(20).plot(kind="barh", figsize=(7,7), legend=False, x="model")

plt.title("Visitas promedio de window shoppers")
plt.xlabel("Cantidad de visitas")
plt.ylabel("Modelo")
# Out:
# Text(0,0.5,'Modelo')

# %% [markdown]
# # 5. Análisis de ventas

# %% [markdown]
# ## 5.1 Calidad de productos vendidos

# %%
ventas = df_eventos.loc[df_eventos["event"] == "conversion",["condition","total"]]

# %%
ventas.groupby("condition", as_index=False).sum()
# Out:
#             condition  total
# 0                 Bom    538
# 1  Bom - Sem Touch ID     22
# 2           Excelente    258
# 3           Muito Bom    352
# 4                Novo      2

# %% [raw]
# De los datos obtenidos hay 2 que resaltan, la bajísima cantidad de ventas de productos con estado "Bom - Sem Touch ID" y "Novo". Hay varias explicaciones posibles para los mismos
# 1) El sitio ofrece una baja cantidad de productos en esas condiciones
# 2) Los productos en esas condiciones tienen muy poco éxito
# 3) Los productos con esas condiciones fueron cargados erroneamente (El de "Bom - Sem Touch ID" por ejemplo parece ser un subtipo de "Bom")

# %% [markdown]
# Para confirmar los puntos 1 y 2 necesitariamos datos que no tenemos por lo tanto vamos a tomar la opción 3 como valida y descartar los casos con estas dos condiciones.

# %%
ventas = ventas.loc[ventas["condition"].isin(["Bom", "Muito Bom", "Excelente"]), :]

# %%
ventas_totales = ventas.groupby("condition",as_index=False).sum()

# %%
ventas_totales
# Out:
#    condition  total
# 0        Bom    538
# 1  Excelente    258
# 2  Muito Bom    352

# %%
ventas_totales.plot(kind="pie",y="total",autopct='%1.1f%%', ax=plt.subplot(121, aspect='equal'),
 startangle=90, shadow=False, labels=ventas_totales["condition"], legend = False, figsize=(10,10))

plt.axis("off")
# Out:
# (-1.25, 1.25, -1.25, 1.25)

# %% [markdown]
# Como podemos observar, a menor "calidad" del producto mayores son las ventas. Los motivos pueden ser varios, por ejemplo pueden llegar a preferir comprar el producto completamente nuevo a comprar uno en estado "excelente". También hay que tener en cuenta que se trata de un sitio que vende celulares usuarios por lo que la gente que ingresa al sitio esta previamente dispuesta a sacrificar un poco de calidad por un mejor precio.

# %% [markdown]
# ## 5.2 Arrepentidos

# %% [markdown]
# Los arrepentidos son las personas que llegaron a instancias de checkout pero nunca realizaron la compra.

# %%
checkouts = df_eventos.loc[df_eventos["event"] == "checkout",["timestamp","person","sku","model"]]
ventas = df_eventos.loc[df_eventos["event"] == "conversion",["timestamp","person", "sku", "model"]]

# %%
checkouts = checkouts.rename(index=str, columns={"timestamp" : "fecha_checkout"})
ventas = ventas.rename(index=str, columns={"timestamp" : "fecha_venta"})

# %%
# Me quedo con un unico checkout por combinacion de persona y producto
checkouts = checkouts.groupby(["person", "sku"], as_index=False).head(1)

# %%
merged = checkouts.merge(ventas, how="left", left_on=["person", "sku", "model"], right_on=["person", "sku", "model"])

# %%
# Obtengo los checkouts sin ventas
checkouts_sin_ventas = merged.loc[merged["fecha_venta"].isnull(),["sku", "model"]]
checkouts_sin_ventas["cantidad"] = 1

# %% [markdown]
# Ahora puedo rankear los productos que más checkouts tuvieron sin haber sido vendidos

# %%
checkouts_sin_ventas = checkouts_sin_ventas.groupby(["sku", "model"], as_index=False).sum()

# %%
checkouts_sin_ventas.nlargest(10, "cantidad")
# Out:
#           sku                   model  cantidad
# 1301   6371.0       Samsung Galaxy J5       411
# 1295   6357.0       Samsung Galaxy J5       405
# 896    2831.0                iPhone 6       310
# 1316   6413.0       Samsung Galaxy J7       275
# 894    2830.0                iPhone 6       246
# 1264   6023.0               iPhone 5s       230
# 1740   8443.0       Samsung Galaxy S7       229
# 890    2829.0                iPhone 6       219
# 445   12758.0       Samsung Galaxy S8       216
# 1085   3371.0  Samsung Galaxy S6 Flat       206

# %% [markdown]
# Esta tabla me muestra los productos que más arrepentidos tienen, pero también se puede agrupar por modelo.

# %%
checkouts_sin_ventas = checkouts_sin_ventas.drop(columns="sku")
checkouts_sin_ventas = checkouts_sin_ventas.groupby("model", as_index=False).sum()

# %%
checkouts_sin_ventas.nlargest(20, "cantidad")
# Out:
#                         model  cantidad
# 171                  iPhone 6      2981
# 170                 iPhone 5s      2368
# 173                 iPhone 6S      2130
# 85          Samsung Galaxy J5      1769
# 120         Samsung Galaxy S7      1181
# 175                  iPhone 7      1143
# 122         Samsung Galaxy S8      1042
# 176             iPhone 7 Plus       869
# 121    Samsung Galaxy S7 Edge       785
# 119    Samsung Galaxy S6 Flat       782
# 93    Samsung Galaxy J7 Prime       775
# 89          Samsung Galaxy J7       702
# 179                 iPhone SE       590
# 172             iPhone 6 Plus       576
# 174            iPhone 6S Plus       526
# 117    Samsung Galaxy S6 Edge       518
# 169                 iPhone 5c       490
# 123    Samsung Galaxy S8 Plus       469
# 34   Motorola Moto G2 3G Dual       451
# 41      Motorola Moto G4 Plus       440

# %%
checkouts_sin_ventas.nlargest(20,"cantidad").plot(kind="bar", x="model", y="cantidad", figsize=(7,7), legend=False)

# %% [markdown]
# A partir de esta tabla se puede tomar medidas para motivar al usuario al terminar esa compra, las estrategias van desde las económicas como ofrecer descuentos o garantías extendidas hasta algo más técnico como un cambio en la UI.

# %% [markdown]
# ## 5.3 Ventas por Marca y Modelo

# %% [markdown]
# En esta etapa se analizaron las relaciones entre las ventas de los productos y los usuarios

# %% [markdown]
# ### 5.3.1 Ventas por usuario

# %%
df_eventos_checkout = df_eventos[df_eventos['event']=='checkout']
df_eventos_checkout
# Out:
#                    timestamp     event    person  url      sku  \
# 1010734                  Samsung Galaxy S7                 Bom    32GB
# 1010763             Samsung Galaxy S6 Flat           Excelente    32GB
# 1010767                          iPhone 5s           Muito Bom    64GB
# 1010779                          iPhone 6S           Muito Bom    64GB
# 1010787                  Samsung Galaxy J5                 Bom    16GB
# 1010801   Samsung Galaxy Core Plus Duos TV           Muito Bom     4GB
# 1010809       Samsung Galaxy J2 4G Duos TV                 Bom     8GB
# 1010838                           iPhone 6  Bom - Sem Touch ID    16GB
# 1010848                     Sony Xperia Z2                 Bom    16GB
# 1010879                          iPhone 5c           Excelente     8GB
# 1010887       Samsung Galaxy J7 2016 Metal                 Bom    16GB
# 1010948                  Samsung Galaxy S7           Muito Bom    32GB
# 1010983              Samsung Galaxy J5 PRO           Muito Bom    32GB
# 1011010                      iPhone 7 Plus           Excelente   128GB
# 1011014  Samsung Galaxy Gran Prime Duos TV           Muito Bom     8GB
# 1011043                          iPhone 6S           Excelente    64GB
# 1011052             Samsung Galaxy A3 Duos                 Bom    16GB
# 1011057                  Samsung Galaxy J5                 Bom    16GB
# 1011180              Motorola Moto X Force           Excelente    64GB
# 1011186                          iPhone 5s           Muito Bom    32GB
# 1011204                           iPhone 7                 Bom    32GB
# 1011230            Samsung Galaxy J7 Prime                 Bom    32GB
# 1011234                  Samsung Galaxy J5                 Bom    16GB
# 1011239                           iPhone 6                 Bom   128GB
# 1011247   Samsung Galaxy Core Plus Duos TV           Excelente     4GB
# 1011283             Samsung Galaxy S7 Edge           Muito Bom    32GB
# 1011287             Samsung Galaxy S7 Edge                 Bom    32GB
#
#                   color skus  ...  operating_system_version browser_version  \
# 3        Cinza espacial  NaN  ...                       NaN             NaN
# 7               Dourado  NaN  ...                       NaN             NaN
# 44                Preto  NaN  ...                       NaN             NaN
# 85                Preto  NaN  ...                       NaN             NaN
# 86                Preto  NaN  ...                       NaN             NaN
# 94               Branco  NaN  ...                       NaN             NaN
# 95               Branco  NaN  ...                       NaN             NaN
# 103               Preto  NaN  ...                       NaN             NaN
# 110      Cinza espacial  NaN  ...                       NaN             NaN
# 114               Preto  NaN  ...                       NaN             NaN
# 137             Dourado  NaN  ...                       NaN             NaN
# 204              Branco  NaN  ...                       NaN             NaN
# 216                Rosa  NaN  ...                       NaN             NaN
# 219              Branco  NaN  ...                       NaN             NaN
# 225               Preto  NaN  ...                       NaN             NaN
# 226            Prateado  NaN  ...                       NaN             NaN
# 233             Dourado  NaN  ...                       NaN             NaN
# 257               Preto  NaN  ...                       NaN             NaN
# 271              Branco  NaN  ...                       NaN             NaN
# 299               Preto  NaN  ...                       NaN             NaN
# 326      Cinza espacial  NaN  ...                       NaN             NaN
# 334      Cinza espacial  NaN  ...                       NaN             NaN
# 361            Prateado  NaN  ...                       NaN             NaN
# 366             Dourado  NaN  ...                       NaN             NaN
# 367             Dourado  NaN  ...                       NaN             NaN
# 386           Ouro Rosa  NaN  ...                       NaN             NaN
# 390               Preto  NaN  ...                       NaN             NaN
# 480               Preto  NaN  ...                       NaN             NaN
# 489             Dourado  NaN  ...                       NaN             NaN
# 646               Preto  NaN  ...                       NaN             NaN
# ...                 ...  ...  ...                       ...             ...
# 1010700         Dourado  NaN  ...                       NaN             NaN
# 1010722        Ametista  NaN  ...                       NaN             NaN
# 1010730         Dourado  NaN  ...                       NaN             NaN
# 1010734         Dourado  NaN  ...                       NaN             NaN
# 1010763           Preto  NaN  ...                       NaN             NaN
# 1010767        Prateado  NaN  ...                       NaN             NaN
# 1010779       Ouro Rosa  NaN  ...                       NaN             NaN
# 1010787         Dourado  NaN  ...                       NaN             NaN
# 1010801          Branco  NaN  ...                       NaN             NaN
# 1010809         Dourado  NaN  ...                       NaN             NaN
# 1010838  Cinza espacial  NaN  ...                       NaN             NaN
# 1010848           Preto  NaN  ...                       NaN             NaN
# 1010879          Branco  NaN  ...                       NaN             NaN
# 1010887         Dourado  NaN  ...                       NaN             NaN
# 1010948           Prata  NaN  ...                       NaN             NaN
# 1010983           Preto  NaN  ...                       NaN             NaN
# 1011010         Dourado  NaN  ...                       NaN             NaN
# 1011014          Branco  NaN  ...                       NaN             NaN
# 1011043  Cinza espacial  NaN  ...                       NaN             NaN
# 1011052          Branco  NaN  ...                       NaN             NaN
# 1011057           Preto  NaN  ...                       NaN             NaN
# 1011180           Preto  NaN  ...                       NaN             NaN
# 1011186         Dourado  NaN  ...                       NaN             NaN
# 1011204     Preto Matte  NaN  ...                       NaN             NaN
# 1011230           Preto  NaN  ...                       NaN             NaN
# 1011234         Dourado  NaN  ...                       NaN             NaN
# 1011239         Dourado  NaN  ...                       NaN             NaN
# 1011247          Branco  NaN  ...                       NaN             NaN
# 1011283           Preto  NaN  ...                       NaN             NaN
# 1011287           Prata  NaN  ...                       NaN             NaN
#
#             timestamp_fecha timestamp_diaDelAnio timestamp_diaDeLaSemana  \
# 3       2018-05-31 23:38:40                  151                       3
# 7       2018-05-29 13:29:35                  149                       1
# 44      2018-05-24 11:34:32                  144                       3
# 85      2018-04-06 05:14:58                   96                       4
# 86      2018-04-06 05:18:15                   96                       4
# 94      2018-05-04 18:50:21                  124                       4
# 95      2018-05-17 04:45:15                  137                       3
# 103     2018-05-17 00:11:26                  137                       3
# 110     2018-06-08 12:19:50                  159                       4
# 114     2018-05-29 12:56:27                  149                       1
# 137     2018-02-01 23:33:52                   32                       3
# 204     2018-02-15 22:10:01                   46                       3
# 216     2018-02-16 00:25:21                   47                       4
# 219     2018-02-16 00:27:43                   47                       4
# 225     2018-05-19 03:36:24                  139                       5
# 226     2018-06-12 19:44:12                  163                       1
# 233     2018-05-30 16:05:55                  150                       2
# 257     2018-05-28 22:52:08                  148                       0
# 271     2018-06-07 21:42:39                  158                       3
# 299     2018-06-14 20:30:48                  165                       3
# 326     2018-06-12 23:44:34                  163                       1
# 334     2018-06-15 00:41:19                  166                       4
# 361     2018-05-30 18:35:08                  150                       2
# 366     2018-05-16 22:42:30                  136                       2
# 367     2018-06-09 05:28:39                  160                       5
# 386     2018-05-28 19:53:54                  148                       0
# 390     2018-06-13 16:14:07                  164                       2
# 480     2018-06-07 17:30:57                  158                       3
# 489     2018-06-06 21:56:46                  157                       2
# 646     2018-05-17 15:37:31                  137                       3
# 1010763                      Tuesday     Samsung     Galaxy            S6
# 1010767                      Tuesday      iPhone         5s          None
# 1010779                     Thursday      iPhone         6S          None
# 1010787                       Monday     Samsung     Galaxy            J5
# 1010801                     Thursday     Samsung     Galaxy          Core
# 1010809                     Thursday     Samsung     Galaxy            J2
# 1010838                       Monday      iPhone          6          None
# 1010848                    Wednesday        Sony     Xperia            Z2
# 1010879                    Wednesday      iPhone         5c          None
# 1010887                       Monday     Samsung     Galaxy            J7
# 1010948                       Friday     Samsung     Galaxy            S7
# 1010983                       Friday     Samsung     Galaxy            J5
# 1011010                       Friday      iPhone          7          Plus
# 1011014                     Thursday     Samsung     Galaxy          Gran
# 1011043                     Saturday      iPhone         6S          None
# 1011052                    Wednesday     Samsung     Galaxy            A3
# 1011057                       Friday     Samsung     Galaxy            J5
# 1011180                    Wednesday    Motorola       Moto             X
# 1011186                       Friday      iPhone         5s          None
# 1011204                     Thursday      iPhone          7          None
# 1011230                       Monday     Samsung     Galaxy            J7
# 1011234                       Friday     Samsung     Galaxy            J5
# 1011239                       Monday      iPhone          6          None
# 1011247                      Tuesday     Samsung     Galaxy          Core
# 1011283                       Monday     Samsung     Galaxy            S7
# 1011287                       Monday     Samsung     Galaxy            S7
#
#         total
# 3           1
# 7           1
# 44          1
# 85          1
# 86          1
# 94          1
# 95          1
# 103         1
# 110         1
# 114         1
# 137         1
# 204         1
# 216         1
# 219         1
# 225         1
# 226         1
# 233         1
# 257         1
# 271         1
# 299         1
# 326         1
# 334         1
# 361         1
# 366         1
# 367         1
# 386         1
# 390         1
# 480         1
# 489         1
# 646         1
# ...       ...
# 1010700     1
# 1010722     1
# 1010730     1
# 1010734     1
# 1010763     1
# 1010767     1
# 1010779     1
# 1010787     1
# 1010801     1
# 1010809     1
# 1010838     1
# 1010848     1
# 1010879     1
# 1010887     1
# 1010948     1
# 1010983     1
# 1011010     1
# 1011014     1
# 1011043     1
# 1011052     1
# 1011057     1
# 1011180     1
# 1011186     1
# 1011204     1
# 1011230     1
# 1011234     1
# 1011239     1
# 1011247     1
# 1011283     1
# 1011287     1
#
# [33735 rows x 31 columns]

# %%
df_eventos_groupby_event_checkout = df_eventos_checkout.groupby(['model']).sum()
df_eventos_groupby_event_checkout = df_eventos_groupby_event_checkout[['total']].reset_index()
df_eventos_groupby_event_checkout.set_index('model', inplace=True)

# %%
df_eventos_groupby_checkout_top10 = df_eventos_groupby_event_checkout.sort_values('total', ascending=False).head(10)
df_eventos_groupby_checkout_top10
# Out:
#                          total
# model
# iPhone 6                  3295
# iPhone 5s                 2744
# iPhone 6S                 2308
# Samsung Galaxy J5         1918
# Samsung Galaxy S7         1234
# iPhone 7                  1205
# Samsung Galaxy S8         1074
# iPhone 7 Plus              924
# Samsung Galaxy J7 Prime    866
# Samsung Galaxy S6 Flat     844

# %%
df_eventos_groupby_checkout_top10.plot(kind='bar',stacked=True, rot=90, figsize=(15,10),color=['green'], fontsize=13)
plt.title('Top 10 - Modelo mas vendidos', fontsize=20);
plt.ylabel('Cantidad', fontsize=20);
plt.xlabel('Modelo de Celular', fontsize=20);

# %% [markdown]
# Vemos que predomina en los primeros 10 tanto Apple como Samsung como marcas favoritas al momento de elegir un producto.

# %% [markdown]
# ### 5.3.2 Marcas más vendidas

# %%
df_eventos_groupby_event_checkout_marca = df_eventos_checkout.groupby(['model_marca']).sum()
df_eventos_groupby_event_checkout_marca = df_eventos_groupby_event_checkout_marca[['total']].reset_index()
df_eventos_groupby_event_checkout_marca.set_index('model_marca', inplace=True)

# %%
df_eventos_groupby_checkout_marca_top5 = df_eventos_groupby_event_checkout_marca.sort_values('total', ascending=False).head(5)
df_eventos_groupby_checkout_marca_top5
# Out:
#              total
# model_marca
# Samsung      14707
# iPhone       14082
# Motorola      3738
# LG             562
# Lenovo         272

# %%
df_eventos_groupby_checkout_marca_top5.plot(kind='bar',stacked=True, rot=90, figsize=(15,10),color=['red'], fontsize=13)
plt.title('Top 5 - Total de Ventas por Marcas (checkout)', fontsize=20);
plt.ylabel('Cantidad', fontsize=16);
plt.xlabel('Marca', fontsize=20);
leyenda=plt.legend(['Total'],fontsize=12,title='Marca',frameon=True,facecolor='white',edgecolor='gray')
leyenda.get_frame().set_linewidth(1.0)

# %% [markdown]
# Aca encontramos como primer insigth que si bien los primeros 3 modelos más vendidos son de Apple, en cantidad total de ventas, Samsung supera a su rival directo Apple. Uno de los opciones sea la variedad de modelos de Samsung vs los ofrecidos por Apple

# %%
df_eventos_groupby_event_checkout_dia = df_eventos_checkout.groupby(['model_marca','timestamp_diaDeLaSemana_desc','timestamp_diaDeLaSemana']).sum()
df_eventos_groupby_event_checkout_dia = df_eventos_groupby_event_checkout_dia[['total']].reset_index()
df_eventos_groupby_event_checkout_dia.set_index('timestamp_diaDeLaSemana_desc','timestamp_diaDeLaSemana', inplace=True)

# %%
df_eventos_groupby_event_checkout_dia.sort_values(['timestamp_diaDeLaSemana','total'], ascending=False).head(20)
# Out:
#                              model_marca  timestamp_diaDeLaSemana  total
# timestamp_diaDeLaSemana_desc
# Sunday                           Samsung                        6   1432
# Sunday                            iPhone                        6   1337
# Sunday                          Motorola                        6    265
# Sunday                                LG                        6     48
# Sunday                            Lenovo                        6     26
# Sunday                              Sony                        6     20
# Sunday                           Quantum                        6      4
# Sunday                              iPad                        6      3
# Sunday                              Asus                        6      2
# Saturday                         Samsung                        5   1504
# Saturday                          iPhone                        5   1480
# Saturday                        Motorola                        5    374
# Saturday                              LG                        5     55
# Saturday                            Sony                        5     24
# Saturday                          Lenovo                        5     20
# Saturday                            iPad                        5      9
# Saturday                            Asus                        5      8
# Friday                           Samsung                        4   2287
# Friday                            iPhone                        4   2110
# Friday                          Motorola                        4    646

# %%
df_eventos_groupby_event_checkout_dia[df_eventos_groupby_event_checkout_dia['model_marca']=='Samsung'].sort_values('timestamp_diaDeLaSemana', ascending=True).head(100)
# Out:
#                              model_marca  timestamp_diaDeLaSemana  total
# timestamp_diaDeLaSemana_desc
# Monday                           Samsung                        0   2074
# Tuesday                          Samsung                        1   2502
# Wednesday                        Samsung                        2   2517
# Thursday                         Samsung                        3   2391
# Friday                           Samsung                        4   2287
# Saturday                         Samsung                        5   1504
# Sunday                           Samsung                        6   1432

# %%
df_eventos_groupby_event_checkout_dia2 = df_eventos_groupby_event_checkout_dia.reset_index()
df_eventos_groupby_event_checkout_dia2
# Out:
#    timestamp_diaDeLaSemana_desc model_marca  timestamp_diaDeLaSemana  total
# 0                        Friday        Asus                        4     13
# 1                        Monday        Asus                        0      9
# 2                      Saturday        Asus                        5      8
# 3                        Sunday        Asus                        6      2
# 4                      Thursday        Asus                        3     14
# 5                       Tuesday        Asus                        1      6
# 6                     Wednesday        Asus                        2     11
# 7                        Friday          LG                        4     85
# 8                        Monday          LG                        0     98
# 9                      Saturday          LG                        5     55
# 10                       Sunday          LG                        6     48
# 11                     Thursday          LG                        3     80
# 12                      Tuesday          LG                        1     93
# 13                    Wednesday          LG                        2    103
# 14                       Friday      Lenovo                        4     52
# 15                       Monday      Lenovo                        0     41
# 16                     Saturday      Lenovo                        5     20
# 17                       Sunday      Lenovo                        6     26
# 18                     Thursday      Lenovo                        3     44
# 19                      Tuesday      Lenovo                        1     51
# 20                    Wednesday      Lenovo                        2     38
# 21                       Friday    Motorola                        4    646
# 22                       Monday    Motorola                        0    502
# 23                     Saturday    Motorola                        5    374
# 24                       Sunday    Motorola                        6    265
# 25                     Thursday    Motorola                        3    681
# 26                      Tuesday    Motorola                        1    648
# 27                    Wednesday    Motorola                        2    622
# 28                       Friday     Quantum                        4      5
# 29                       Monday     Quantum                        0      2
# ..                          ...         ...                      ...    ...
# 32                      Tuesday     Quantum                        1      3
# 33                    Wednesday     Quantum                        2      3
# 34                       Friday     Samsung                        4   2287
# 35                       Monday     Samsung                        0   2074
# 36                     Saturday     Samsung                        5   1504
# 37                       Sunday     Samsung                        6   1432
# 38                     Thursday     Samsung                        3   2391
# 39                      Tuesday     Samsung                        1   2502
# 40                    Wednesday     Samsung                        2   2517
# 41                       Friday        Sony                        4     37
# 42                       Monday        Sony                        0     38
# 43                     Saturday        Sony                        5     24
# 44                       Sunday        Sony                        6     20
# 45                     Thursday        Sony                        3     28
# 46                      Tuesday        Sony                        1     36
# 47                    Wednesday        Sony                        2     35
# 48                       Friday        iPad                        4      9
# 49                       Monday        iPad                        0     18
# 50                     Saturday        iPad                        5      9
# 51                       Sunday        iPad                        6      3
# 52                     Thursday        iPad                        3      9
# 53                      Tuesday        iPad                        1     13
# 54                    Wednesday        iPad                        2     11
# 55                       Friday      iPhone                        4   2110
# 56                       Monday      iPhone                        0   1839
# 57                     Saturday      iPhone                        5   1480
# 58                       Sunday      iPhone                        6   1337
# 59                     Thursday      iPhone                        3   2310
# 60                      Tuesday      iPhone                        1   2574
# 61                    Wednesday      iPhone                        2   2432
#
# [62 rows x 4 columns]

# %%
top_df_eventos_groupby_event_checkout_dia2_2 = pd.pivot_table(df_eventos_groupby_event_checkout_dia2,values=['total'],
               columns='model_marca',aggfunc=np.sum,fill_value=0)
top_df_eventos_groupby_event_checkout_dia2_2
# Out:
# model_marca  Asus   LG  Lenovo  Motorola  Quantum  Samsung  Sony  iPad  iPhone
# total          63  562     272      3738       19    14707   218    72   14082
